# %% [markdown]
# <a href="https://colab.research.google.com/github/tt1120git/IT612/blob/main/IT612_JS_Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
#
# console.log('hello world!');
#
# function addTax(price, rate) {
#   return (1 + rate) * price;
# }
#
# console.log(addTax(10, 0.1))
# console.log(addTax(67841, 0.14))
#
#
#
# function createBurner(secret, limit) {
#   let lim = limit
#   const whisper = function () {
#     if (lim > 0) {
#       lim = lim - 1
#       console.log(secret)
#     } else console.log("...")
#   }
#   return whisper
# }
#
# let burn = createBurner("Secret!!!", 3)
# burn()
# burn()
# burn()
# burn()
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# hello world!
# 11
# 77338.74
# Secret!!!
# Secret!!!
# Secret!!!
# ...
